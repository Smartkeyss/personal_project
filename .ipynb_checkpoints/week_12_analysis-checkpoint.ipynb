# %%
import pandas as pd
from haversine import haversine, Unit

# %%
bike = pd.read_csv('2017-fordgobike-tripdata.csv')

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519700 entries, 0 to 519699
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             519700 non-null  int64
#  1   start_time               519700 non-null  object
#  2   end_time                 519700 non-null  object
#  3   start_station_id         519700 non-null  int64
#  4   start_station_name       519700 non-null  object
#  5   start_station_latitude   519700 non-null  float64
#  6   start_station_longitude  519700 non-null  float64
#  7   end_station_id           519700 non-null  int64
#  8   end_station_name         519700 non-null  object
#  9   end_station_latitude     519700 non-null  float64
#  10  end_station_longitude    519700 non-null  float64
#  11  bike_id                  519700 non-null  int64
#  12  user_type                519700 non-null  object
#  13  member_birth_year        453159 non-null  float64
#  14  member_gender            453238 non-null  object
# dtypes: float64(5), int64(4), object(6)
# memory usage: 59.5+ MB

# %%
bike.head(20)
# Out:
#     duration_sec                start_time                  end_time  \
# 0          80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1          78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2          45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3          62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4          43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
# 5           9226  2017-12-31 22:51:00.9180  2018-01-01 01:24:47.1660
# 6           4507  2017-12-31 23:49:28.4220  2018-01-01 01:04:35.6190
# 7           4334  2017-12-31 23:46:37.1960  2018-01-01 00:58:51.2110
# 8           4150  2017-12-31 23:37:07.5480  2018-01-01 00:46:18.3080
# 9           4238  2017-12-31 23:35:38.1450  2018-01-01 00:46:17.0530
# 10          3292  2017-12-31 23:46:32.4030  2018-01-01 00:41:24.6050
# 11          3177  2017-12-31 23:48:11.7570  2018-01-01 00:41:09.5810
# 12          2183  2017-12-31 23:52:55.5810  2018-01-01 00:29:18.7430
# 13          2170  2017-12-31 23:52:55.9370  2018-01-01 00:29:06.9240
# 14          2697  2017-12-31 23:35:23.2220  2018-01-01 00:20:20.8130
# 15          1544  2017-12-31 23:53:38.9430  2018-01-01 00:19:23.0470
# 16          1474  2017-12-31 23:54:40.1460  2018-01-01 00:19:14.3510
# 17          1397  2017-12-31 23:55:09.6860  2018-01-01 00:18:26.7210
# 18          1532  2017-12-31 23:52:49.4970  2018-01-01 00:18:21.9530
# 19          1216  2017-12-31 23:46:33.9930  2018-01-01 00:06:50.0580
#
#     start_station_id                                 start_station_name  \
# 0                 74                              Laguna St at Hayes St
# 1                284  Yerba Buena Center for the Arts (Howard St at ...
# 2                245                             Downtown Berkeley BART
# 3                 60                               8th St at Ringold St
# 4                239                      Bancroft Way at Telegraph Ave
# 5                 30     San Francisco Caltrain (Townsend St at 4th St)
# 6                259                            Addison St at Fourth St
# 7                284  Yerba Buena Center for the Arts (Howard St at ...
# 8                 20    Mechanics Monument Plaza (Market St at Bush St)
# 9                 20    Mechanics Monument Plaza (Market St at Bush St)
# 10               284  Yerba Buena Center for the Arts (Howard St at ...
# 11               284  Yerba Buena Center for the Arts (Howard St at ...
# 12                67  San Francisco Caltrain Station 2  (Townsend St...
# 13                67  San Francisco Caltrain Station 2  (Townsend St...
# 14                66                              3rd St at Townsend St
# 15                14                              Clay St at Battery St
# 16                14                              Clay St at Battery St
# 17                78                                Folsom St at 9th St
# 18                78                                Folsom St at 9th St
# 19                 4                        Cyril Magnin St at Ellis St
#
#     start_station_latitude  start_station_longitude  end_station_id  \
# 0                37.776435              -122.426244              43
# 1                37.784872              -122.400876              96
# 2                37.870348              -122.267764             245
# 3                37.774520              -122.409449               5
# 4                37.868813              -122.258764             247
# 5                37.776598              -122.395282              30
# 6                37.866249              -122.299371             259
# 7                37.784872              -122.400876             284
# 8                37.791300              -122.399051              20
# 9                37.791300              -122.399051              20
# 10               37.784872              -122.400876              22
# 11               37.784872              -122.400876              22
# 12               37.776639              -122.395526              24
# 13               37.776639              -122.395526              24
# 14               37.778742              -122.392741              23
# 15               37.795001              -122.399970              27
# 16               37.795001              -122.399970              27
# 17               37.773717              -122.411647              15
# 18               37.773717              -122.411647              15
# 19               37.785881              -122.408915             123
#
#                                      end_station_name  end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                               Dolores St at 15th St             37.766210
# 2                              Downtown Berkeley BART             37.870348
# 3        Powell St BART Station (Market St at 5th St)             37.783899
# 4                           Fulton St at Bancroft Way             37.867789
# 5      San Francisco Caltrain (Townsend St at 4th St)             37.776598
# 6                             Addison St at Fourth St             37.866249
# 7   Yerba Buena Center for the Arts (Howard St at ...             37.784872
# 8     Mechanics Monument Plaza (Market St at Bush St)             37.791300
# 9     Mechanics Monument Plaza (Market St at Bush St)             37.791300
# 10                              Howard St at Beale St             37.789756
# 11                              Howard St at Beale St             37.789756
# 12                              Spear St at Folsom St             37.789677
# 13                              Spear St at Folsom St             37.789677
# 14                      The Embarcadero at Steuart St             37.791464
# 15                            Beale St at Harrison St             37.788059
# 16                            Beale St at Harrison St             37.788059
# 17  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 18  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 19                               Folsom St at 19th St             37.760594
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 0             -122.415929       96    Customer             1987.0
# 1             -122.426614       88    Customer             1965.0
# 2             -122.267764     1094    Customer                NaN
# 3             -122.408445     2831    Customer                NaN
# 4             -122.265896     3167  Subscriber             1997.0
# 5             -122.395282     1487    Customer                NaN
# 6             -122.299371     3539    Customer             1991.0
# 7             -122.400876     1503    Customer                NaN
# 8             -122.399051     3125    Customer                NaN
# 9             -122.399051     2543    Customer                NaN
# 10            -122.394643     3058    Customer                NaN
# 11            -122.394643     3197    Customer                NaN
# 12            -122.390428     2311  Subscriber             1990.0
# 13            -122.390428     3717  Subscriber             1990.0
# 14            -122.391034     3452    Customer                NaN
# 15            -122.391865      558  Subscriber             1980.0
# 16            -122.391865     3646  Subscriber             1979.0
# 17            -122.394203     1667    Customer                NaN
# 18            -122.394203     3114  Subscriber             1988.0
# 19            -122.414817     1473  Subscriber             1971.0
#
#    member_gender
# 0           Male
# 1         Female
# 2            NaN
# 3            NaN
# 4         Female
# 5            NaN
# 6         Female
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12          Male
# 13          Male
# 14           NaN
# 15        Female
# 16          Male
# 17           NaN
# 18         Other
# 19          Male

# %%
# Check if there are any records with out start location details
bike.start_station_latitude.value_counts().sum() ==  bike.start_station_longitude.value_counts().sum()
# Out:
# True

# %%
# Check if there are any records with out end location details
bike.end_station_latitude.value_counts().sum() == bike.end_station_longitude.value_counts().sum()
# Out:
# True

# %%
#Check if there are any duplicated records
bike.duplicated().sum()
# Out:
# 0

# %%
def haversine_func(data):
    lon1 = data["start_station_longitude"]
    lat1 = data["start_station_latitude"]
    lon2 = data["end_station_longitude"]
    lat2 = data["end_station_latitude"]
    return haversine((lat1,lon1),(lat2,lon2))

# %%
bike['haversine_dist'] = bike.apply(lambda bike : haversine_func(bike), axis = 1)

# %% [markdown]
# ##  2 - Calculate the duration in seconds of each trip

# %%
bike['start_time']=pd.to_datetime(bike['start_time'])

# %%
bike['end_time']=pd.to_datetime(bike['end_time'])

# %%
bike["trip_duration_in_sec"] = bike["end_time"]-bike["start_time"]

# %%
bike["trip_duration_in_sec"]
# Out:
# 0        0 days 22:15:10.591000
# 1        0 days 21:53:20.775000
# 2        0 days 12:42:48.472000
# 3        0 days 17:16:12.895000
# 4        0 days 12:06:43.570000
#                   ...
# 519695   0 days 00:07:15.910000
# 519696   0 days 00:07:11.459000
# 519697   0 days 00:07:04.840000
# 519698   0 days 00:06:06.051000
# 519699   0 days 00:03:08.961000
# Name: trip_duration_in_sec, Length: 519700, dtype: timedelta64[ns]

# %%
bike["trip_duration_in_sec"] = bike["trip_duration_in_sec"].astype("timedelta64[s]")
bike["trip_duration_in_sec"]
# Out:
# 0         80110.0
# 1         78800.0
# 2         45768.0
# 3         62172.0
# 4         43603.0
#            ...
# 519695      435.0
# 519696      431.0
# 519697      424.0
# 519698      366.0
# 519699      188.0
# Name: trip_duration_in_sec, Length: 519700, dtype: float64

# %%
bike.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         80110 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1         78800 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2         45768 2017-12-31 22:45:48.411 2018-01-01 11:28:36.883
# 3         62172 2017-12-31 17:31:10.636 2018-01-01 10:47:23.531
# 4         43603 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.776435              -122.426244              43
# 1               37.784872              -122.400876              96
# 2               37.870348              -122.267764             245
# 3               37.774520              -122.409449               5
# 4               37.868813              -122.258764             247
#
#                                     end_station_name  end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                              Dolores St at 15th St             37.766210
# 2                             Downtown Berkeley BART             37.870348
# 3       Powell St BART Station (Market St at 5th St)             37.783899
# 4                          Fulton St at Bancroft Way             37.867789
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.415929       96    Customer             1987.0
# 1            -122.426614       88    Customer             1965.0
# 2            -122.267764     1094    Customer                NaN
# 3            -122.408445     2831    Customer                NaN
# 4            -122.265896     3167  Subscriber             1997.0
#
#   member_gender  haversine_dist  trip_duration_in_sec
# 0          Male        0.942932               80110.0
# 1        Female        3.069731               78800.0
# 2           NaN        0.000000               45768.0
# 3           NaN        1.046624               62172.0
# 4        Female        0.636340               43603.0

# %%
bike["user_type"].unique()
# Out:
# array(['Customer', 'Subscriber'], dtype=object)

# %% [markdown]
# ### By assuming each minute cost 0.35 cent calculate the fee for each trip

# %%
def cost_of_trip(trip_duration):
    cost_of_a_trip = (trip_duration / 60) * 0.35
    return cost_of_a_trip

# %%
bike["Cost of trip"] = bike["trip_duration_in_sec"].apply(cost_of_trip)

# %%
bike.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         80110 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1         78800 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2         45768 2017-12-31 22:45:48.411 2018-01-01 11:28:36.883
# 3         62172 2017-12-31 17:31:10.636 2018-01-01 10:47:23.531
# 4         43603 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.776435              -122.426244              43
# 1               37.784872              -122.400876              96
# 2               37.870348              -122.267764             245
# 3               37.774520              -122.409449               5
# 4               37.868813              -122.258764             247
#
#                                     end_station_name  end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                              Dolores St at 15th St             37.766210
# 2                             Downtown Berkeley BART             37.870348
# 3       Powell St BART Station (Market St at 5th St)             37.783899
# 4                          Fulton St at Bancroft Way             37.867789
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.415929       96    Customer             1987.0
# 1            -122.426614       88    Customer             1965.0
# 2            -122.267764     1094    Customer                NaN
# 3            -122.408445     2831    Customer                NaN
# 4            -122.265896     3167  Subscriber             1997.0
#
#   member_gender  haversine_dist  trip_duration_in_sec  Cost of trip
# 0          Male        0.942932               80110.0    467.308333
# 1        Female        3.069731               78800.0    459.666667
# 2           NaN        0.000000               45768.0    266.980000
# 3           NaN        1.046624               62172.0    362.670000
# 4        Female        0.636340               43603.0    254.350833

# %% [markdown]
# ### Calculating the total distance for each bike and listing top 10

# %%
bike_total_dist = bike.groupby('bike_id')[['haversine_dist']].sum().sort_values(by='haversine_dist', ascending=False)
bike_total_dist.head(10)
# Out:
#          haversine_dist
# bike_id
# 68           743.369490
# 2178         721.182231
# 256          671.916150
# 235          670.161992
# 2049         656.828082
# 441          656.642275
# 2226         647.823268
# 796          646.867722
# 190          640.294175
# 2365         639.412701

# %%
 bike['member_gender'].fillna("Not_filled", inplace = True)

# %%
bike
# Out:
#         duration_sec              start_time                end_time  \
# 0              80110 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1              78800 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2              45768 2017-12-31 22:45:48.411 2018-01-01 11:28:36.883
# 3              62172 2017-12-31 17:31:10.636 2018-01-01 10:47:23.531
# 4              43603 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
# ...              ...                     ...                     ...
# 519695           435 2017-06-28 10:00:54.528 2017-06-28 10:08:10.438
# 519696           431 2017-06-28 09:56:39.631 2017-06-28 10:03:51.090
# 519697           424 2017-06-28 09:47:36.347 2017-06-28 09:54:41.187
# 519698           366 2017-06-28 09:47:41.664 2017-06-28 09:53:47.715
# 519699           188 2017-06-28 09:49:46.377 2017-06-28 09:52:55.338
#
#         start_station_id                                 start_station_name  \
# 0                     74                              Laguna St at Hayes St
# 1                    284  Yerba Buena Center for the Arts (Howard St at ...
# 2                    245                             Downtown Berkeley BART
# 3                     60                               8th St at Ringold St
# 4                    239                      Bancroft Way at Telegraph Ave
# ...                  ...                                                ...
# 519695                81                                 Berry St at 4th St
# 519696                66                              3rd St at Townsend St
# 519697                21   Montgomery St BART Station (Market St at 2nd St)
# 519698                58                               Market St at 10th St
# 519699                25                                Howard St at 2nd St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.776435              -122.426244              43
# 1                    37.784872              -122.400876              96
# 2                    37.870348              -122.267764             245
# 3                    37.774520              -122.409449               5
# 4                    37.868813              -122.258764             247
# ...                        ...                      ...             ...
# 519695               37.775880              -122.393170              45
# 519696               37.778742              -122.392741             321
# 519697               37.789625              -122.400811              48
# 519698               37.776619              -122.417385              59
# 519699               37.787522              -122.397405              48
#
#                                          end_station_name  \
# 0       San Francisco Public Library (Grove St at Hyde...
# 1                                   Dolores St at 15th St
# 2                                  Downtown Berkeley BART
# 3            Powell St BART Station (Market St at 5th St)
# 4                               Fulton St at Bancroft Way
# ...                                                   ...
# 519695                                5th St at Howard St
# 519696                                      5th at Folsom
# 519697                                2nd St at S Park St
# 519698                        S Van Ness Ave at Market St
# 519699                                2nd St at S Park St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.778768            -122.415929       96    Customer
# 1                  37.766210            -122.426614       88    Customer
# 2                  37.870348            -122.267764     1094    Customer
# 3                  37.783899            -122.408445     2831    Customer
# 4                  37.867789            -122.265896     3167  Subscriber
# ...                      ...                    ...      ...         ...
# 519695             37.781752            -122.405127      400  Subscriber
# 519696             37.780146            -122.403071      316  Subscriber
# 519697             37.782411            -122.392706      240  Subscriber
# 519698             37.774814            -122.418954      669  Subscriber
# 519699             37.782411            -122.392706      117  Subscriber
#
#         member_birth_year member_gender  haversine_dist  trip_duration_in_sec  \
# 0                  1987.0          Male        0.942932               80110.0
# 1                  1965.0        Female        3.069731               78800.0
# 2                     NaN    Not_filled        0.000000               45768.0
# 3                     NaN    Not_filled        1.046624               62172.0
# 4                  1997.0        Female        0.636340               43603.0
# ...                   ...           ...             ...                   ...
# 519695             1991.0          Male        1.237187                 435.0
# 519696             1973.0          Male        0.921190                 431.0
# 519697             1985.0        Female        1.072757                 424.0
# 519698             1981.0          Male        0.243515                 366.0
# 519699             1984.0          Male        0.702462                 188.0
#
#         Cost of trip
# 0         467.308333
# 1         459.666667
# 2         266.980000
# 3         362.670000
# 4         254.350833
# ...              ...
# 519695      2.537500
# 519696      2.514167
# 519697      2.473333
# 519698      2.135000
# 519699      1.096667
#
# [519700 rows x 18 columns]

# %%
no_of_trips_per_station_sorted = bike.groupby(["start_station_id", "member_gender"]).count()["duration_sec"].unstack()

# %%
no_of_trips_per_station_sorted["sum"] = no_of_trips_per_station_sorted.sum(axis =1)

# %%
no_of_trips_per_station_sorted['Female_Ratio'] = (no_of_trips_per_station_sorted['Female'] / no_of_trips_per_station_sorted["sum"]) * 100
no_of_trips_per_station_sorted['Male_Ratio'] = (no_of_trips_per_station_sorted['Male'] / no_of_trips_per_station_sorted["sum"]) * 100
no_of_trips_per_station_sorted['others_Ratio'] = (no_of_trips_per_station_sorted['Other'] / no_of_trips_per_station_sorted["sum"]) * 100
no_of_trips_per_station_sorted['Not_filled_Ratio'] = (no_of_trips_per_station_sorted['Not_filled'] / no_of_trips_per_station_sorted["sum"]) * 100

# %%
no_of_trips_per_station_sorted.sort_values(by = "sum", ascending= False).head(10)
# Out:
# member_gender     Female    Male  Not_filled  Other      sum  Female_Ratio  \
# start_station_id
# 15                2819.0  8586.0      3678.0  104.0  15187.0     18.561928
# 6                 1938.0  7444.0      4163.0  119.0  13664.0     14.183255
# 30                2035.0  9813.0       617.0   81.0  12546.0     16.220309
# 67                2105.0  9409.0       428.0  113.0  12055.0     17.461634
# 58                1870.0  9005.0      1050.0   35.0  11960.0     15.635452
# 21                1631.0  8367.0      1293.0   43.0  11334.0     14.390330
# 81                2302.0  7773.0       816.0   65.0  10956.0     21.011318
# 3                 1768.0  6070.0      2240.0   64.0  10142.0     17.432459
# 22                1980.0  7512.0       320.0  114.0   9926.0     19.947612
# 16                1740.0  6532.0       978.0   97.0   9347.0     18.615599
#
# member_gender     Male_Ratio  others_Ratio  Not_filled_Ratio
# start_station_id
# 15                 56.535195      0.684796         24.218081
# 6                  54.478923      0.870902         30.466920
# 30                 78.216165      0.645624          4.917902
# 67                 78.050601      0.937370          3.550394
# 58                 75.292642      0.292642          8.779264
# 21                 73.822128      0.379389         11.408152
# 81                 70.947426      0.593282          7.447974
# 3                  59.850128      0.631039         22.086373
# 22                 75.680032      1.148499          3.223857
# 16                 69.883385      1.037766         10.463250
