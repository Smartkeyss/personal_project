# %% [markdown]
# # Import necessary Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Read the csv

# %%
tr_houses = pd.read_csv("train.csv")
te_houses = pd.read_csv("test.csv")
submission = pd.read_csv("sample_submission.csv")

# %% [markdown]
# # Description of the Data

# %%
tr_houses.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
te_houses.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
tr_houses.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
te_houses.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
tr_houses.shape
# Out:
# (1460, 81)

# %%
te_houses.shape
# Out:
# (1459, 80)

# %%
tr_houses.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
tr_houses.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
tr_houses.isna().sum().sort_values(ascending= False)[10:30]
# Out:
# BsmtHalfBath     0
# BsmtFullBath     0
# GrLivArea        0
# LowQualFinSF     0
# 2ndFlrSF         0
# 1stFlrSF         0
# Electrical       0
# GarageType       0
# GarageFinish     0
# HeatingQC        0
# GarageCars       0
# SaleCondition    0
# SaleType         0
# YrSold           0
# MoSold           0
# MiscVal          0
# PoolArea         0
# ScreenPorch      0
# 3SsnPorch        0
# EnclosedPorch    0
# dtype: int64

# %%
te_houses.nunique().sort_values()[40:70]
# Out:
# HouseStyle         7
# BsmtFinType1       7
# Functional         8
# Condition1         9
# OverallCond        9
# OverallQual       10
# SaleType          10
# TotRmsAbvGrd      12
# MoSold            12
# 3SsnPorch         13
# Exterior1st       14
# LowQualFinSF      15
# Exterior2nd       16
# MSSubClass        16
# Neighborhood      25
# MiscVal           26
# YearRemodAdd      61
# ScreenPorch       75
# GarageYrBlt       97
# YearBuilt        106
# EnclosedPorch    131
# BsmtFinSF2       162
# OpenPorchSF      203
# WoodDeckSF       263
# MasVnrArea       303
# 2ndFlrSF         407
# GarageArea       459
# BsmtFinSF1       670
# TotalBsmtSF      736
# 1stFlrSF         789
# dtype: int64

# %%
tr_houses.nunique().sort_values().head(20)
# Out:
# CentralAir      2
# Utilities       2
# Street          2
# Alley           2
# BsmtHalfBath    3
# LandSlope       3
# GarageFinish    3
# HalfBath        3
# PavedDrive      3
# PoolQC          3
# FullBath        4
# MasVnrType      4
# BsmtExposure    4
# ExterQual       4
# MiscFeature     4
# BsmtFullBath    4
# Fence           4
# KitchenQual     4
# BsmtCond        4
# Fireplaces      4
# dtype: int64

# %%
te_houses["PoolQC"].unique()
# Out:
# array([nan, 'Ex', 'Gd'], dtype=object)

# %%
null_columns = te_houses.isna().sum().sort_values(ascending= False).head(6).index

# %%
tr_houses = tr_houses.drop(null_columns, axis=1)

# %%
te_houses = te_houses.drop(null_columns,axis = 1)

# %%
str_cols = tr_houses.columns[tr_houses.dtypes==object]
tr_houses[str_cols] = tr_houses[str_cols].fillna("not_filled")

# %%
tr_houses
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
tr_houses.nunique().sort_values(ascending= True)
# Out:
# CentralAir         2
# Street             2
# Utilities          2
# PavedDrive         3
# BsmtHalfBath       3
#                 ...
# 1stFlrSF         753
# BsmtUnfSF        780
# GrLivArea        861
# LotArea         1073
# Id              1460
# Length: 75, dtype: int64

# %%
tr_houses.isna().sum().sort_values(ascending= False)
# Out:
# GarageYrBlt    81
# MasVnrArea      8
# HalfBath        0
# Fireplaces      0
# Functional      0
#                ..
# ExterQual       0
# MasVnrType      0
# Exterior2nd     0
# Exterior1st     0
# SalePrice       0
# Length: 75, dtype: int64

# %%
tr_houses["MasVnrArea"] = tr_houses["MasVnrArea"].fillna(tr_houses["MasVnrArea"].mean().round())
tr_houses["GarageYrBlt"] = tr_houses["GarageYrBlt"].fillna(tr_houses["GarageYrBlt"].mean().round())

# %%
str_cols_2 = te_houses.columns[te_houses.dtypes==object]
te_houses[str_cols] = te_houses[str_cols_2].fillna("not_filled")

# %%
te_houses
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0     1461          20       RH    11622   Pave      Reg         Lvl
# 1     1462          20       RL    14267   Pave      IR1         Lvl
# 2     1463          60       RL    13830   Pave      IR1         Lvl
# 3     1464          60       RL     9978   Pave      IR1         Lvl
# 4     1465         120       RL     5005   Pave      IR1         HLS
# ...    ...         ...      ...      ...    ...      ...         ...
# 1454  2915         160       RM     1936   Pave      Reg         Lvl
# 1455  2916         160       RM     1894   Pave      Reg         Lvl
# 1456  2917          20       RL    20000   Pave      Reg         Lvl
# 1457  2918          85       RL    10441   Pave      Reg         Lvl
# 1458  2919          60       RL     9627   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
te_houses.nunique().sort_values(ascending= True)["GarageArea"]
# Out:
# 459

# %%
non_cat = te_houses[te_houses.columns[te_houses.dtypes!=object]].isna().sum().sort_values(ascending = False)
Non_cat = non_cat[:11].index
Non_cat
# Out:
# Index(['GarageYrBlt', 'MasVnrArea', 'BsmtHalfBath', 'BsmtFullBath',
#        'BsmtUnfSF', 'GarageCars', 'GarageArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'TotalBsmtSF', 'OpenPorchSF'],
#       dtype='object')

# %%
te_houses["BsmtFullBath"] = te_houses["BsmtFullBath"].fillna(te_houses["BsmtFullBath"].mean().round())
te_houses["BsmtHalfBath"] = te_houses["BsmtHalfBath"].fillna(te_houses["BsmtHalfBath"].mean().round())
te_houses["GarageYrBlt"] = te_houses["GarageYrBlt"].fillna(te_houses["GarageYrBlt"].mean().round())
te_houses["MasVnrArea"] = te_houses["MasVnrArea"].fillna(te_houses["MasVnrArea"].mean().round())
te_houses["BsmtUnfSF"] = te_houses["BsmtUnfSF"].fillna(te_houses["BsmtUnfSF"].mean().round())
te_houses["BsmtFinSF1"] = te_houses["BsmtFinSF1"].fillna(te_houses["BsmtFinSF1"].mean().round())
te_houses["GarageArea"] = te_houses["GarageArea"].fillna(te_houses["GarageArea"].mean().round())
te_houses["TotalBsmtSF"] = te_houses["TotalBsmtSF"].fillna(te_houses["TotalBsmtSF"].mean().round())
te_houses["GarageCars"] = te_houses["GarageCars"].fillna(te_houses["GarageArea"].mean().round())
te_houses["BsmtFinSF2"] = te_houses["BsmtFinSF2"].fillna(te_houses["BsmtFinSF2"].mean().round())

# %%
Categorical_Columns = str_cols

# %%
 num_columns = tr_houses.columns[tr_houses.dtypes!=object]

# %%
see = tr_houses[num_columns].nunique().sort_values().head(15)
num_but_cat = see.index

# %%
sen = tr_houses[num_columns].nunique().sort_values().tail(23)
Num_columns = sen.index[:-1]
Num_columns
# Out:
# Index(['MSSubClass', '3SsnPorch', 'MiscVal', 'LowQualFinSF', 'YearRemodAdd',
#        'ScreenPorch', 'GarageYrBlt', 'YearBuilt', 'EnclosedPorch',
#        'BsmtFinSF2', 'OpenPorchSF', 'WoodDeckSF', 'MasVnrArea', '2ndFlrSF',
#        'GarageArea', 'BsmtFinSF1', 'SalePrice', 'TotalBsmtSF', '1stFlrSF',
#        'BsmtUnfSF', 'GrLivArea', 'LotArea'],
#       dtype='object')

# %%
Categorical_Columns[:]
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
sns.color_palette("pastel")

fig = plt.figure(figsize=(20,140))
for index,col in enumerate(tr_houses[Categorical_Columns].columns):
    plt.subplot(12,4,index+1)
    sns.countplot(x=tr_houses[Categorical_Columns].iloc[:,index], data=tr_houses[Categorical_Columns], palette='Set3')
    plt.ylabel('COUNT', size = 18,color="black" )
    plt.xlabel(col, fontsize = 18,color="black" )

    plt.xticks(size = 15,color="red", rotation = 45 )
    plt.yticks(size = 15,color="black" )
    
fig.tight_layout(pad=1.0)

# %%
sns.color_palette("pastel")

fig = plt.figure(figsize=(20,140))
for index,col in enumerate(tr_houses[num_but_cat].columns):
    plt.subplot(10,2,index+1)
    sns.countplot(x=tr_houses[num_but_cat].iloc[:,index], data=tr_houses[num_but_cat], palette='Set3')
    plt.ylabel('COUNT', size = 18,color="black" )
    plt.xlabel(col, fontsize = 18,color="black" )

    plt.xticks(size = 15,color="red", rotation = 45 )
    plt.yticks(size = 15,color="black" )
    
fig.tight_layout(pad=1.0)

# %%
sns.color_palette("pastel")

fig = plt.figure(figsize=(20,140))
for index,col in enumerate(tr_houses[Num_columns].columns):
    plt.subplot(13,2,index+1)
    sns.histplot(x=col, data=tr_houses[Num_columns])
    plt.ylabel('COUNT', size = 18,color="black" )
    plt.xlabel(col, fontsize = 18,color="black" )

    plt.xticks(size = 15,color="red", rotation = 45 )
    plt.yticks(size = 15,color="black" )
    
fig.tight_layout(pad=1.0)

# %%
plt.figure(figsize=(30,30))
sns.heatmap(tr_houses[num_columns].corr())
plt.xticks(size = 15,color="red", rotation = 45 )
plt.yticks(size = 15,color="black", rotation = 45)
plt.show()

# %%
X_train= tr_houses.iloc[:, :-1]
Y_train = tr_houses.iloc[:, -1]
X_tests = te_houses.iloc[:, :]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
labelencoder = LabelEncoder()

# %%
for i in Categorical_Columns:
    X_train[i] = labelencoder.fit_transform(X_train[i])
    X_tests[i] = labelencoder.fit_transform(X_tests[i])

# %%
plt.figure(figsize=(30,30))
sns.heatmap(tr_houses.corr())
plt.xticks(size = 15,color="red", rotation = 45 )
plt.yticks(size = 15,color="black", rotation = 45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13560\2407448735.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tr_houses.corr())

# %%
X_train
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0        1          60         3     8450       1         3            3
# 1        2          20         3     9600       1         3            3
# 2        3          60         3    11250       1         0            3
# 3        4          70         3     9550       1         0            3
# 4        5          60         3    14260       1         0            3
# ...    ...         ...       ...      ...     ...       ...          ...
# 1455  1456          60         3     7917       1         3            3
# 1456  1457          20         3    13175       1         3            3
# 1457  1458          70         3     9042       1         3            3
# 1458  1459          20         3     9717       1         3            3
# 1459  1460          20         3     9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
ct = ColumnTransformer([(i, OneHotEncoder(), [i])], remainder = 'passthrough')
X_train = ct.fit_transform(X_train)
X_tests = ct.fit_transform(X_tests)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state= 42)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_tests)

# %%
print(y_pred)
# Out:
# [104088.94628906 153917.10546875 166070.76953125 ... 161966.15039062
#  115151.40722656 240494.18652344]

# %%
Y =submission["SalePrice"]

# %%
regressor.intercept_
# Out:
# -7353349283474.054

# %%
r2_score(Y, y_pred )
# Out:
# -94.68305466049706

# %%
te_houses["BsmtFullBath"].mean()
# Out:
# 0.43385880740233035
